# %% [markdown]
# <a href="https://colab.research.google.com/github/sum-young/26-1-DL-from-scratch-study/blob/main/Chapter_02/Week02_DeepLearning_from_Scratch_CH02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AND 게이트
def AND(x1, x2):
  w1, w2, theta = 0.1, 0.1, 0.1
  tmp = x1*w1+x2*w2

  if tmp <= theta:
    return 0 #임곗값 이하면 0 (비활성화)
  elif tmp > theta:
    return 1

print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %%
import numpy as np

x = np.array([0,1]) #입력
w = np.array([0.5, 0.5]) #가중치
b = -0.7

np.sum(x*w)+b
# Out:
# np.float64(-0.19999999999999996)

# %%
#가중치와 편향 구현한 AND 게이트
import numpy as np

def AND(x1,x2):
  x = np.array([x1,x2])
  w = np.array([0.5, 0.5])
  b = -0.7

  tmp = np.sum(x*w)+b
  if tmp <= 0:
    return 0
  elif tmp > 0:
    return 1

print(AND(0,0))
print(AND(1,0))
print(AND(0,1))
print(AND(1,1))
# Out:
# 0
# 0
# 0
# 1

# %%
#NAND 게이트

def NAND(x1, x2):
  x = np.array([x1,x2])
  w = np.array([-0.5,-0.5])
  b = 0.7

  tmp = np.sum(x*w)+b

  if tmp <= 0:
    return 0
  elif tmp > 0:
    return 1

print(NAND(0,0))
print(NAND(0,1))
print(NAND(1,0))
print(NAND(1,1))
# Out:
# 1
# 1
# 1
# 0

# %%
#OR 게이트
def OR(x1, x2):
  x = np.array([x1,x2])
  w = np.array([0.2,0.2])
  b = -0.1

  tmp = np.sum(x*w)+b

  if tmp <= 0:
    return 0
  elif tmp > 0:
    return 1

print(OR(0,0))
print(OR(0,1))
print(OR(1,0))
print(OR(1,1))
# Out:
# 0
# 1
# 1
# 1

# %%
#XOR 게이트

def XOR (x1, x2):
  s1 = NAND(x1,x2)
  s2 = OR(x1,x2)
  tmp = AND(s1,s2)

  if tmp <= 0:
    return 0
  elif tmp > 0:
    return 1

print(XOR(0,0))
print(XOR(0,1))
print(XOR(1,0))
print(XOR(1,1))
# Out:
# 0
# 1
# 1
# 0
